# %% [markdown]
# ## 1.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df=pd.read_csv("USA_housing.csv")
pd.set_option('display.max_columns', None) #show all columns
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %% [markdown]
# ## 2.

# %%
df.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
df.tail(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4990      52723.876555             5.452237                   8.124571
# 4991      74102.191890             5.657841                   7.683993
# 4992      87499.125743             6.403473                   4.836091
# 4993      69639.140896             5.007510                   7.778375
# 4994      73060.846226             5.293682                   6.312253
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4990                          6.39     14802.088438  4.795006e+05
# ...

# %%
df.sample(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4004      75867.231110             6.588824                   6.756786
# 4471      94494.384349             7.240434                   6.700316
# 2986      84703.628230             5.918211                   6.883671
# 957       71857.571409             6.425893                   6.225548
# 2851      79619.864271             4.752153                   8.354962
# 3511      48855.353788             5.392023                   7.289207
# 4587      62524.556360             5.799667                   7.601512
# 3538      53599.800859             6.553829                   8.937600
# 1956      69269.938153             6.186291                   6.181705
# 4831      68186.031691             6.889046                   8.432093
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4004                          3.11     32319.547497  1.408428e+06
# ...

# %% [markdown]
# ## 3.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df["Avg. Area Income"].value_counts()
# Out:
# 73056.526114    1
# 68661.247464    1
# 67310.036953    1
# 70944.653449    1
# 65935.612609    1
#                ..
# 93455.952957    1
# 86818.068756    1
# 52446.266856    1
# 86818.565885    1
# 93822.308480    1
# Name: Avg. Area Income, Length: 5000, dtype: int64

# %%
df["Avg. Area House Age"].value_counts()
# Out:
# 6.150796    1
# 5.888005    1
# 5.959945    1
# 6.171113    1
# 6.844164    1
#            ..
# 5.105172    1
# 3.942531    1
# 6.752351    1
# 7.031774    1
# 4.899966    1
# Name: Avg. Area House Age, Length: 5000, dtype: int64

# %%
df["Avg. Area Number of Rooms"].value_counts()
# Out:
# 6.952633    1
# 6.635434    1
# 7.199332    1
# 5.288573    1
# 7.805453    1
#            ..
# 7.989124    1
# 8.075309    1
# 8.440491    1
# 6.699769    1
# 5.620100    1
# Name: Avg. Area Number of Rooms, Length: 5000, dtype: int64

# %%
df["Area Population"].value_counts()
# Out:
# 24534.371052    1
# 17597.041128    1
# 28470.827408    1
# 36105.069611    1
# 42425.776352    1
#                ..
# 25948.644214    1
# 27027.056485    1
# 24233.061458    1
# 43122.574176    1
# 34493.747170    1
# Name: Area Population, Length: 5000, dtype: int64

# %%
df["Price"].value_counts()
# Out:
# 8.001101e+05    1
# 1.430274e+05    1
# 1.300303e+06    1
# 3.909484e+05    1
# 1.159954e+06    1
#                ..
# 6.716617e+05    1
# 1.280231e+06    1
# 4.594464e+05    1
# 6.804187e+05    1
# 1.194083e+06    1
# Name: Price, Length: 5000, dtype: int64

# %%
df["Address"].value_counts()
# Out:
# 91733 Baker Orchard\nSouth Kyle, KS 37301                       1
# 1098 Patterson Passage Apt. 935\nEast Jessicaburgh, IN 87581    1
# 4277 Katherine Tunnel Suite 986\nHallview, LA 24505             1
# 163 Pamela Landing\nFosterberg, WI 71392                        1
# 666 Patrick Islands\nEast Chaseside, CT 39131                   1
#                                                                ..
# 2430 Samuel Stravenue\nPort Williamtown, NM 37798-8316          1
# 4901 Michelle Estate Suite 734\nNew Aimeemouth, MH 31261        1
# 086 Ellis Ford Suite 326\nChristophermouth, GU 30825-6006       1
# 725 Wood Flats\nLake Josephtown, MO 38832-8878                  1
# 9297 Cole Highway\nPatrickhaven, DC 02945-8988                  1
# Name: Address, Length: 5000, dtype: int64

# %% [markdown]
# ## 4.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# ## 5.

# %%
sns.pairplot(df)

# %% [markdown]
# ## 6.

# %%
fig=plt.figure(figsize=(10,8))
sns.distplot(df["Price"])
# Out:
# /Users/macintosh/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig=plt.figure(figsize=(10,8))
sns.distplot(df["Area Population"])
# Out:
# /Users/macintosh/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig=plt.figure(figsize=(10,8))
sns.distplot(df["Avg. Area Number of Rooms"])
# Out:
# /Users/macintosh/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 7.

# %%
df_corr=df_corr=df[["Avg. Area Income","Avg. Area House Age","Avg. Area Number of Rooms","Area Population","Price"]]
sns.heatmap(df_corr.corr())

# %% [markdown]
# ## 8.

# %%
fig=plt.figure(figsize=(12,12))
plt.scatter(df["Avg. Area Income"],df["Price"])

# %% [markdown]
# ## 9.

# %%
fig=plt.figure(figsize=(12,12))
plt.scatter(df["Avg. Area Income"],df["Area Population"])

# %% [markdown]
# ## 10.

# %%
fig=plt.figure(figsize=(12,12))
sns.distplot(df["Price"])
# Out:
# /Users/macintosh/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 11.

# %%
fig=plt.figure(figsize=(12,12))
sns.boxplot(x=df["Price"])

# %% [markdown]
# ## 12.

# %%
from sklearn.model_selection import train_test_split #เครื่องมือช่วยแบ่งข้อมูล
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
x=df["Avg. Area Income"]
y=df["Price"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %% [markdown]
# ## 13.

# %%
x_train=np.array(x_train).reshape(-1,1)
x_test=np.array(x_test).reshape(-1,1)

# %%
lm =LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print("graph intercept: ",lm.intercept_)
print("graph coefficiency: ",lm.coef_)
# Out:
# graph intercept:  -222138.45320528583
# graph coefficiency:  [21.20966364]

# %% [markdown]
# ## 14.

# %%
predicted=lm.predict(x_test)
print("MAE: ",metrics.mean_absolute_error(y_test,predicted))
print("MSE: ",metrics.mean_squared_error(y_test,predicted))
print("RMSE: ",np.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# MAE:  216840.73673143954
# MSE:  73824970420.6649
# RMSE:  271707.50895156525

# %% [markdown]
# ## 15.

# %%
fig=plt.figure(figsize=(12,8))
sns.distplot(y_test-predicted,bins=50)
# Out:
# /Users/macintosh/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 16.

# %%
fig=plt.figure(figsize=(12,10))
plt.scatter(x_test,y_test,color="blue",label="real data")
plt.plot(x_test,predicted,color="red",label="predicted regression price")
plt.xlabel("Average Area Income")
plt.ylabel("Price")
plt.legend()

# %% [markdown]
# ## 17.

# %%
x3=df[["Avg. Area Income","Avg. Area House Age","Avg. Area Number of Rooms","Area Population"]]
y=df["Price"]
x3
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Area Population
# 0        23086.800503
# 1        40173.072174
# 2        36882.159400
# ...

# %%
x3_train,x3_test,y_train,y_test=train_test_split(x3,y,test_size=0.3,random_state=100)

# %%
lm3 =LinearRegression()
lm3.fit(x3_train,y_train) 
print("graph intercept: ",lm3.intercept_)
print("graph coefficiency: ",lm3.coef_)
# Out:
# graph intercept:  -2633696.284269359
# graph coefficiency:  [2.16033365e+01 1.65673398e+05 1.20514632e+05 1.52575338e+01]

# %% [markdown]
# ## 18.

# %%
predicted3=lm3.predict(x3_test)
print("MAE: ",metrics.mean_absolute_error(y_test,predicted3))
print("MSE: ",metrics.mean_squared_error(y_test,predicted3))
print("RMSE: ",np.sqrt(metrics.mean_squared_error(y_test,predicted3)))
# Out:
# MAE:  81548.15274962185
# MSE:  10345781003.094492
# RMSE:  101714.21239480002

# %% [markdown]
# ## 19.

# %%
predicted3=lm3.predict(x3_test)
fig=plt.figure(figsize=(10,8))
sns.distplot((y_test-predicted3),bins=50)
# Out:
# /Users/macintosh/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
print("RMSE of Linear Regression: ",np.sqrt(metrics.mean_squared_error(y_test,predicted)))
print("RMSE of Multi Linear Regression: ",np.sqrt(metrics.mean_squared_error(y_test,predicted3)))
# Out:
# RMSE of Linear Regression:  271707.50895156525
# RMSE of Multi Linear Regression:  101714.21239480002

# %%
m=np.sqrt(metrics.mean_squared_error(y_test,predicted))
n=np.sqrt(metrics.mean_squared_error(y_test,predicted3))
print("RMSE ของ Multi Linear Regression น้อยกว่าของ Linear Regression อยู่ {0:.2f}".format(m-n))
# Out:
# RMSE ของ Multi Linear Regression น้อยกว่าของ Linear Regression อยู่ 169993.30
